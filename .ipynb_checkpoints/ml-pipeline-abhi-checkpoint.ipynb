# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import json
from google.cloud import storage
from news_data_call import *
from user_definition import *
from datetime import datetime
from pyspark.sql import SparkSession
from pyspark.sql.types import *

import csv
import pandas as pd

from user_definition import *

from news_data_call import *
from user_definition import *

# %%
def read_json_from_gcs(bucket_name, blob_name, service_account_key_file):
    storage_client = storage.Client.from_service_account_json(service_account_key_file)
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(blob_name)
    data_string = blob.download_as_text()
    data = json.loads(data_string)
    return data

def gcs_to_mongob(uri,data,sources_name):


    client = MongoClient(uri, server_api=ServerApi('1'))

    client.admin.command('ping')
    # Retrieve news data from Google Cloud Storage
    db = client['news']
    collection = db[sources_name]
    collection.insert_many(data)
    return collection


uri = "mongodb+srv://waffleiron:zNkFSHTfTGroBXRq@waffleironcluster.7uzj7t2.mongodb.net/?retryWrites=true&w=majority&appName=WaffleIronCluster"
# Example usage: service_account_key_file, bucket_name, "waffle.json"

#news_data = read_json_from_gcs(bucket_name, "2024-03-01_cnn.json", service_account_key_file)
#data = gcs_to_mongob(uri, news_data, "2024-03-01_cnn")

def mongod_to_spark(data, sources_name):
    data = list(data.find({}))

    # Create a Spark session
    spark = SparkSession.builder \
        .appName("MongoDB to DataFrame") \
        .getOrCreate()
    csv_file = f"{sources_name}.csv"
    headers = data[0].keys()
    with open(csv_file, 'w', newline='', encoding='utf-8') as file:
        writer = csv.DictWriter(file, fieldnames=headers)
    
    # Write column headers
        writer.writeheader()
    
    # Write data rows
        for row in data:
            writer.writerow(row)



    dfs = pd.read_csv(f"{sources_name}.csv")
    dfs = dfs.drop(columns=["videos", "images"])
    dfs["publisher"] = dfs["publisher"].apply(lambda x: eval(x)['title'])
    
    
    schema = StructType([
        StructField("_id", StringType(), True),
        StructField("title", StringType(), True),
        StructField("top_image", StringType(), True),
        StructField("url", StringType(), True),
        StructField("date", StringType(), True),
        StructField("short_description", StringType(), True),
        StructField("text", StringType(), True),
        StructField("publisher", StringType(), True)
        ])

    df = spark.createDataFrame(dfs, schema=schema)
    df.show()
    return df

# %%
spark = SparkSession.builder \
        .appName("MongoDB to DataFrame") \
        .getOrCreate()

# %%
dfs = spark.read.json("ml_data/2024-03-01_foxnews.json")
dfs.show(5)
# Out:
# +----------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------+
# |      date|              images|           publisher|   short_description|                text|               title|           top_image|                 url|videos|
# +----------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------+
# |2024-02-29|[https://static.f...|{https://www.foxn...|Kamala Harris pra...|Join Fox News for...|Kamala Harris pra...|https://static.fo...|https://www.foxne...|    []|
# |2024-02-28|[https://a57.foxn...|{https://www.foxn...|Marianne Williams...|Join Fox News for...|Marianne Williams...|https://static.fo...|https://www.foxne...|    []|
# |2024-02-27|[https://a57.foxn...|{https://www.foxn...|NY AG taunts Trum...|Join Fox News for...|NY AG taunts Trum...|https://static.fo...|https://www.foxne...|    []|
# |2024-02-28|[https://static.f...|{https://www.foxn...|Hunter Biden test...|Hunter Biden test...|Hunter Biden test...|https://static.fo...|https://www.foxne...|    []|
# |2024-03-01|[https://a57.foxn...|{https://www.foxn...|Haley slams Trump...|Join Fox News for...|Haley slams Trump...|https://static.fo...|https://www.foxne...|    []|
# +----------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------+
# only showing top 5 rows

# %%
df = pd.read_csv('ml_data/nytimes.csv')

# %%
len(df)
# Out:
# 1

# %%
df = df.drop(columns=["videos", "images"])

# %%
df["publisher"] = df["publisher"].apply(lambda x: eval(x)["title"])
df
# Out:
#                         _id                   title  \
# 0  65e44540b6e58c7773b6f2cd  U.S. Politics - Page 8
#
#                                            top_image  \
# 0  https://static01.nyt.com/newsgraphics/images/i...
#
#                                                url        date  \
# 0  https://www.nytimes.com/section/politics?page=8  2023-11-13
#
#                             short_description  \
# 0  U.S. Politics - Page 8  The New York Times
#
#                                                 text           publisher
# 0  news analysis\n\nFor Democrats Pining for an A...  The New York Times

# %%
schema = StructType(
        [
            StructField("_id", StringType(), True),
            StructField("title", StringType(), True),
            StructField("top_image", StringType(), True),
            StructField("url", StringType(), True),
            StructField("date", StringType(), True),
            StructField("short_description", StringType(), True),
            StructField("text", StringType(), True),
            StructField("publisher", StringType(), True),
        ]
    )

# %%
spark_df = spark.createDataFrame(df, schema=schema)

# %%
spark_df.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 spark_df.show()
#
# File ~/anaconda3/envs/DistributedComputing/lib/python3.11/site-packages/pyspark/sql/dataframe.py:945, in DataFrame.show(self, n, truncate, vertical)
#     885 def show(self, n: int = 20, truncate: Union[bool, int] = True, vertical: bool = False) -> None:
#     886     """Prints the first ``n`` rows to the console.
#     887
#     888     .. versionadded:: 1.3.0
#    (...)
#     943     name | Bob
#     944     """
# --> 945     print(self._show_string(n, truncate, vertical))
#
# File ~/anaconda3/envs/DistributedComputing/lib/python3.11/site-packages/pyspark/sql/dataframe.py:963, in DataFrame._show_string(self, n, truncate, vertical)
#     957     raise PySparkTypeError(
#     958         error_class="NOT_BOOL",
#     959         message_parameters={"arg_name": "vertical", "arg_type": type(vertical).__name__},
#     960     )
#     962 if isinstance(truncate, bool) and truncate:
# --> 963     return self._jdf.showString(n, 20, vertical)
#     964 else:
#     965     try:
#
# File ~/anaconda3/envs/DistributedComputing/lib/python3.11/site-packages/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1314 args_command, temp_args = self._build_args(*args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
# -> 1321 answer = self.gateway_client.send_command(command)
#    1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#
# File ~/anaconda3/envs/DistributedComputing/lib/python3.11/site-packages/py4j/java_gateway.py:1038, in GatewayClient.send_command(self, command, retry, binary)
#    1036 connection = self._get_connection()
#    1037 try:
# -> 1038     response = connection.send_command(command)
#    1039     if binary:
#    1040         return response, self._create_connection_guard(connection)
#
# File ~/anaconda3/envs/DistributedComputing/lib/python3.11/site-packages/py4j/clientserver.py:511, in ClientServerConnection.send_command(self, command)
#     509 try:
#     510     while True:
# --> 511         answer = smart_decode(self.stream.readline()[:-1])
#     512         logger.debug("Answer received: {0}".format(answer))
#     513         # Happens when a the other end is dead. There might be an empty
#     514         # answer before the socket raises an error.
#
# File ~/anaconda3/envs/DistributedComputing/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
# !pip install spark
# Out:
# Collecting spark
#   Downloading spark-0.2.1.tar.gz (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 kB 5.6 kB/s eta 0:00:00:00:0100:02
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: spark
#   Building wheel for spark (setup.py) ... done
#   Created wheel for spark: filename=spark-0.2.1-py3-none-any.whl size=58748 sha256=9b74ec435ac4aed4bcae4e9fb76d861986c096ea935a76fbf12f80dd3b576b58
#   Stored in directory: /Users/ronel/Library/Caches/pip/wheels/67/c2/7c/a53325365fba358ffff35af84a2e14cf88c18052f88acfa5f0
# Successfully built spark
# Installing collected packages: spark
# Successfully installed spark-0.2.1

# %% [markdown]
# # THIS NEXT CELL RIGHT HERE

# %%
import os
import sys
from transformers import pipeline

# Redirect stderr to /dev/null to suppress warning messages
sys.stderr = open(os.devnull, 'w')

sentiment_task = pipeline("sentiment-analysis", model="cardiffnlp/twitter-roberta-base-sentiment-latest", tokenizer="cardiffnlp/twitter-roberta-base-sentiment-latest")
summarizer = pipeline("summarization", model="facebook/bart-large-cnn")
rows = spark_df.collect()

# %%
from collections import defaultdict

# Assuming there is a "date" column in your DataFrame
date_column = "date"

# Create a defaultdict to store misleading scores by date
misleading_scores_by_date = defaultdict(list)

#rows = spark_df.collect()

for batch_df in spark_df.randomSplit([0.1] * 10):  # Adjust batch size as needed
    rows = batch_df.collect()
    for row in rows:
        title = row["title"]
        text = row["text"]
        desc = row["short_description"]
        date = row["date"]  # Change "date" to your actual date column name

        if len(text) > 1024:
            text = text[:1024]

        if len(text.split()) < 130:
            summary = text
        else:
            summary = summarizer(text, max_length=130, min_length=50, do_sample=False)[0]['summary_text']

        text_sentiment = sentiment_task(summary)[0]['label']
        title_sentiment = sentiment_task(title)[0]['label']
        desc_sentiment = sentiment_task(desc)[0]['label']

        if (title_sentiment != text_sentiment) or (text_sentiment != desc_sentiment):
            if (title_sentiment == 'neutral') or (desc_sentiment == 'neutral'):
                misleading_scores_by_date[date].append(1)
                print("Misleadingly opinionated")
            else:
                misleading_scores_by_date[date].append(2)
                print("Clickbait")
        else:
            misleading_scores_by_date[date].append(0)
            print("Good")

# %%
average_scores_by_date = {}
# Calculate and print the average misleading score for each date
for date, scores in misleading_scores_by_date.items():
    average_score = sum(scores) / len(scores) if len(scores) > 0 else 0
    average_scores_by_date[date] = average_score

# %%
import plotly.graph_objects as go
sorted_scores = dict(sorted(average_scores_by_date.items()))

dates = list(sorted_scores.keys())
scores = list(sorted_scores.values())

fig = go.Figure(data=go.Scatter(x=dates, y=scores, mode='lines+markers'))
fig.update_layout(title='Average Misleading Scores by Date',
                      xaxis_title='Date',
                      yaxis_title='Average Misleading Score')
fig.show()

# %%
misleading_score = 0
total_articles = 0

for row in rows:
    title = row["title"]
    text = row["text"]
    if len(text.split()) > 1024:
        text = ' '.join(text.split()[:1024])
    if len(text.split()) < 130:
        summary = text
    else:
        summary = summarizer(text, max_length=130, min_length=50, do_sample=False)[0]['summary_text']
    text_summary_sentiment = sentiment_task(summary)
    title_sentiment = sentiment_task(title)
    article_sentiment_list = [title_sentiment, text_summary_sentiment]
    article_sentiment = [sublist[0] for sublist in article_sentiment_list]
    sentiment_dict = {
        'title': article_sentiment[0]['label'],
        'text': article_sentiment[1]['label'],
    }
    if sentiment_dict['title'] != sentiment_dict['text']:
        if sentiment_dict['title'] == 'neutral':
            misleading_score += 1
            print("Misleadingly opinionated")
        else:
            misleading_score += 2
            print("Clickbait")
    else:
        misleading_score += 0
        print("Good")
    total_articles += 1

print(misleading_score/total_articles)

# %%
len(rows) == total_articles

# %% [markdown]
# # This next cell keeps giving me an error when I call dfs.show().

# %%
spark_df.show()

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, udf
import os
import sys
from pyspark.sql.types import *

# Redirect stderr to /dev/null to suppress warning messages
sys.stderr = open(os.devnull, 'w')

# Define the sentiment analysis function
def check_sentiment(text, title):
    # Include your sentiment analysis code here
    # Replace this with your actual sentiment analysis pipeline
    sys.stderr = open(os.devnull, 'w')
    summarizer = pipeline("summarization", model="facebook/bart-large-cnn")
    if len(text) > 1024:
        text = text[:1024]
    if len(text.split()) < 130:
        summary = text
    else:
        summary = summarizer(text, max_length=130, min_length=10, do_sample=False)[0]['summary_text']
    sentiment_task = pipeline("sentiment-analysis", model="cardiffnlp/twitter-roberta-base-sentiment-latest", tokenizer="cardiffnlp/twitter-roberta-base-sentiment-latest")
    text_summary_sentiment = sentiment_task(summary)
    title_sentiment = sentiment_task(title)
    article_sentiment_list = [title_sentiment, text_summary_sentiment]
    article_sentiment = [sublist[0] for sublist in article_sentiment_list]
    sentiment_dict = {
        'title': article_sentiment[0]['label'],
        'text': article_sentiment[1]['label']
    }
    if sentiment_dict['title'] != sentiment_dict['text']:
        if sentiment_dict['title'] == 'neutral':
            return 1
        else:
            return 2
    else:
        return 0
    
data = spark_df.select(["text", "title", "date", "short_description"])
data.show()

# Initialize Spark session
spark = SparkSession.builder.appName("Apply Clickbait Detection").getOrCreate()

# Assuming 'df' is your existing DataFrame
# Apply sentiment analysis to create 'is_clickbait' column
sentiment_udf = udf(check_sentiment, IntegerType())
x = sentiment_udf(data["text"], data["title"])

dfs = data.withColumn("is_clickbait", x)
# Out:
# +--------------------+--------------------+----------+--------------------+
# |                text|               title|      date|   short_description|
# +--------------------+--------------------+----------+--------------------+
# |Join Fox News for...|Elise Stefanik ey...|2024-03-01|Elise Stefanik ey...|
# |Join Fox News for...|McCaul demands UN...|2024-03-01|McCaul demands UN...|
# |Join Fox News for...|Kamala Harris pra...|2024-02-29|Kamala Harris pra...|
# |Join Fox News for...|Marianne Williams...|2024-02-28|Marianne Williams...|
# |Join Fox News for...|NY AG taunts Trum...|2024-02-27|NY AG taunts Trum...|
# |Hunter Biden test...|Hunter Biden test...|2024-02-28|Hunter Biden test...|
# |Join Fox News for...|Appeals court rul...|2024-03-01|Appeals court rul...|
# |Join Fox News for...|Federal court rul...|2024-02-28|Federal court rul...|
# |The White House i...|White House calls...|2024-02-28|White House calls...|
# |Join Fox News for...|Illinois judge re...|2024-02-29|Illinois judge re...|
# |Join Fox News for...|Biden calls clima...|2024-03-01|Biden calls clima...|
# |Join Fox News for...|Supreme Court div...|2024-02-28|Supreme Court div...|
# |FIRST ON FOX: Rep...|House GOP lawmake...|2024-02-28|House GOP lawmake...|
# |Sen. Mitch McConn...|Mitch McConnell s...|2024-02-28|Mitch McConnell s...|
# |Join Fox News for...|Haley says US wil...|2024-02-23|Haley says US wil...|
# |Join Fox News for...|Legal experts say...|2024-02-29|Legal experts say...|
# |Join Fox News for...|Lloyd Austin to f...|2024-02-29|Lloyd Austin to f...|
# |Join Fox News for...|Key witness in Fa...|2024-02-27|Key witness in Fa...|
# |Join Fox News for...|Americans questio...|2024-02-28|Americans questio...|
# |Join Fox News for...|Jeb Bush comes to...|2024-02-26|Jeb Bush comes to...|
# +--------------------+--------------------+----------+--------------------+
# only showing top 20 rows

# %%
dfs.printSchema()
# Out:
# root
#  |-- text: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- date: string (nullable = true)
#  |-- short_description: string (nullable = true)
#  |-- is_clickbait: integer (nullable = true)

# %%
import time 
start_time = time.time()
dfs.show()
end_time = time.time()
# Out:
# +--------------------+--------------------+----------+--------------------+------------+
# |                text|               title|      date|   short_description|is_clickbait|
# +--------------------+--------------------+----------+--------------------+------------+
# |Join Fox News for...|Elise Stefanik ey...|2024-03-01|Elise Stefanik ey...|           0|
# |Join Fox News for...|McCaul demands UN...|2024-03-01|McCaul demands UN...|           0|
# |Join Fox News for...|Kamala Harris pra...|2024-02-29|Kamala Harris pra...|           2|
# |Join Fox News for...|Marianne Williams...|2024-02-28|Marianne Williams...|           0|
# |Join Fox News for...|NY AG taunts Trum...|2024-02-27|NY AG taunts Trum...|           2|
# |Hunter Biden test...|Hunter Biden test...|2024-02-28|Hunter Biden test...|           2|
# |Join Fox News for...|Appeals court rul...|2024-03-01|Appeals court rul...|           0|
# |Join Fox News for...|Federal court rul...|2024-02-28|Federal court rul...|           0|
# |The White House i...|White House calls...|2024-02-28|White House calls...|           0|
# |Join Fox News for...|Illinois judge re...|2024-02-29|Illinois judge re...|           0|
# |Join Fox News for...|Biden calls clima...|2024-03-01|Biden calls clima...|           0|
# |Join Fox News for...|Supreme Court div...|2024-02-28|Supreme Court div...|           0|
# |FIRST ON FOX: Rep...|House GOP lawmake...|2024-02-28|House GOP lawmake...|           2|
# |Sen. Mitch McConn...|Mitch McConnell s...|2024-02-28|Mitch McConnell s...|           0|
# |Join Fox News for...|Haley says US wil...|2024-02-23|Haley says US wil...|           0|
# |Join Fox News for...|Legal experts say...|2024-02-29|Legal experts say...|           0|
# |Join Fox News for...|Lloyd Austin to f...|2024-02-29|Lloyd Austin to f...|           1|
# |Join Fox News for...|Key witness in Fa...|2024-02-27|Key witness in Fa...|           0|
# |Join Fox News for...|Americans questio...|2024-02-28|Americans questio...|           2|
# |Join Fox News for...|Jeb Bush comes to...|2024-02-26|Jeb Bush comes to...|           2|
# +--------------------+--------------------+----------+--------------------+------------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import avg
dfs = dfs.select(["date", "is_clickbait"])
start_time = time.time()
x = dfs.groupBy("date") \
    .agg(avg("is_clickbait")) \
    .show()
end_time = time.time()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[56], line 6
#       2 dfs = dfs.select(["date", "is_clickbait"])
#       3 start_time = time.time()
#       4 x = dfs.groupBy("date") \
#       5     .agg(avg("is_clickbait")) \
# ----> 6     .show()
#       7 end_time = time.time()
#
# File ~/anaconda3/envs/DistributedComputing/lib/python3.11/site-packages/pyspark/sql/dataframe.py:945, in DataFrame.show(self, n, truncate, vertical)
#     885 def show(self, n: int = 20, truncate: Union[bool, int] = True, vertical: bool = False) -> None:
#     886     """Prints the first ``n`` rows to the console.
#     887
#     888     .. versionadded:: 1.3.0
#    (...)
#     943     name | Bob
#     944     """
# --> 945     print(self._show_string(n, truncate, vertical))
#
# File ~/anaconda3/envs/DistributedComputing/lib/python3.11/site-packages/pyspark/sql/dataframe.py:963, in DataFrame._show_string(self, n, truncate, vertical)
#     957     raise PySparkTypeError(
#     958         error_class="NOT_BOOL",
#     959         message_parameters={"arg_name": "vertical", "arg_type": type(vertical).__name__},
#     960     )
#     962 if isinstance(truncate, bool) and truncate:
# --> 963     return self._jdf.showString(n, 20, vertical)
#     964 else:
#     965     try:
#
# File ~/anaconda3/envs/DistributedComputing/lib/python3.11/site-packages/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1314 args_command, temp_args = self._build_args(*args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
# -> 1321 answer = self.gateway_client.send_command(command)
#    1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#
# File ~/anaconda3/envs/DistributedComputing/lib/python3.11/site-packages/py4j/java_gateway.py:1038, in GatewayClient.send_command(self, command, retry, binary)
#    1036 connection = self._get_connection()
#    1037 try:
# -> 1038     response = connection.send_command(command)
#    1039     if binary:
#    1040         return response, self._create_connection_guard(connection)
#
# File ~/anaconda3/envs/DistributedComputing/lib/python3.11/site-packages/py4j/clientserver.py:511, in ClientServerConnection.send_command(self, command)
#     509 try:
#     510     while True:
# --> 511         answer = smart_decode(self.stream.readline()[:-1])
#     512         logger.debug("Answer received: {0}".format(answer))
#     513         # Happens when a the other end is dead. There might be an empty
#     514         # answer before the socket raises an error.
#
# File ~/anaconda3/envs/DistributedComputing/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
x

# %%
(end_time - start_time)
# Out:
# 132.8341100215912

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, udf
from pyspark.sql.types import *
from transformers import pipeline

# Initialize Spark session
spark = SparkSession.builder.appName("Apply Clickbait Detection").getOrCreate()

# Define the sentiment analysis function
def check_sentiment(text, title):
    # Include your sentiment analysis code here
    # Replace this with your actual sentiment analysis pipeline
    summarizer = pipeline("summarization", model="facebook/bart-large-cnn")
    # Your remaining code for sentiment analysis...

# Register the sentiment analysis UDF
sentiment_udf = udf(check_sentiment, IntegerType())

# Sample data (Assuming 'spark_df' is your existing DataFrame)
data = spark_df.select(["text", "title", "date", "short_description"])
data.show()

# Apply sentiment analysis to create 'is_clickbait' column
dfs = data.withColumn("is_clickbait", sentiment_udf(col("text"), col("title")))

dfs.show()
# Out:
# +--------------------+--------------------+----------+--------------------+
# |                text|               title|      date|   short_description|
# +--------------------+--------------------+----------+--------------------+
# |Join Fox News for...|Elise Stefanik ey...|2024-03-01|Elise Stefanik ey...|
# |Join Fox News for...|Lloyd Austin to f...|2024-02-29|Lloyd Austin to f...|        NULL|
# |Join Fox News for...|Key witness in Fa...|2024-02-27|Key witness in Fa...|        NULL|
# |Join Fox News for...|Americans questio...|2024-02-28|Americans questio...|        NULL|
# |Join Fox News for...|Jeb Bush comes to...|2024-02-26|Jeb Bush comes to...|        NULL|
# +--------------------+--------------------+----------+--------------------+------------+
# only showing top 20 rows

# %%
# Stop Spark session
spark.stop()

# %%
from aggregates_to_mongo import *

# %%
uri = "mongodb+srv://waffleiron:zNkFSHTfTGroBXRq@waffleironcluster.7uzj7t2.mongodb.net/?retryWrites=true&w=majority&appName=WaffleIronCluster"
data = deduplicate_and_aggregate(uri, "2024-03-01_cnn")
data
# Out:
# An error occurred: SSL handshake failed: ac-k1wg4ld-lb.7uzj7t2.mongodb.net:27017: timed out (configured timeouts: connectTimeoutMS: 20000.0ms)
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymongo/pool.py:1282, in _configured_socket(address, options)
#    1281 if HAS_SNI:
# -> 1282     ssl_sock = ssl_context.wrap_socket(sock, server_hostname=host)
#    1283 else:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymongo/pyopenssl_context.py:403, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     399 if do_handshake_on_connect:
#     400     # XXX: If we do hostname checking in a callback we can get rid
#     401     # of this call to do_handshake() since the handshake
#     402     # will happen automatically later.
# --> 403     ssl_conn.do_handshake()
#     404     # XXX: Do this in a callback registered with
#     405     # SSLContext.set_info_callback? See Twisted for an example.
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymongo/pyopenssl_context.py:142, in _sslConn.do_handshake(self, *args, **kwargs)
#     141 def do_handshake(self, *args: Any, **kwargs: Any) -> None:
# --> 142     return self._call(super().do_handshake, *args, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymongo/pyopenssl_context.py:138, in _sslConn._call(self, call, *args, **kwargs)
#     137 if timeout and _time.monotonic() - start > timeout:
# --> 138     raise _socket.timeout("timed out") from None
#     139 continue
#
# TimeoutError: timed out
#
# The above exception was the direct cause of the following exception:
#
# NetworkTimeout                            Traceback (most recent call last)
# File ~/Documents/USF/MSDS_697/waffle-iron/aggregates_to_mongo.py:140, in deduplicate_and_aggregate(uri, sources_name)
#     138 try:
#     139     # Execute the aggregation pipeline
# --> 140     result = collection.aggregate(pipeline)
#     141     # Since aggregate() is lazy, using a loop or similar method to initiate execution might be necessary
#     142     # For example, converting it to a list (if the result set is not too large) or iterating over it
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymongo/collection.py:2720, in Collection.aggregate(self, pipeline, session, let, comment, **kwargs)
#    2719 with self.__database.client._tmp_session(session, close=False) as s:
# -> 2720     return self._aggregate(
#    2721         _CollectionAggregationCommand,
#    2722         pipeline,
#    2723         CommandCursor,
#    2724         session=s,
#    2725         explicit_session=session is not None,
#    2726         let=let,
#    2727         comment=comment,
#    2728         **kwargs,
#    2729     )
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymongo/_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymongo/collection.py:2627, in Collection._aggregate(self, aggregation_command, pipeline, cursor_class, session, explicit_session, let, comment, **kwargs)
#    2617 cmd = aggregation_command(
#    2618     self,
#    2619     cursor_class,
#    (...)
#    2624     user_fields={"cursor": {"firstBatch": 1}},
#    2625 )
# -> 2627 return self.__database.client._retryable_read(
#    2628     cmd.get_cursor,
#    2629     cmd.get_read_preference(session),  # type: ignore[arg-type]
#    2630     session,
#    2631     retryable=not cmd._performs_write,
#    2632 )
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymongo/mongo_client.py:1492, in MongoClient._retryable_read(self, func, read_pref, session, address, retryable)
#    1489 retryable = bool(
#    1490     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    1491 )
# -> 1492 return self._retry_internal(
#    1493     func,
#    1494     session,
#    1495     None,
#    1496     is_read=True,
#    1497     address=address,
#    1498     read_pref=read_pref,
#    1499     retryable=retryable,
#    1500 )
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymongo/_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymongo/mongo_client.py:1462, in MongoClient._retry_internal(self, func, session, bulk, is_read, address, read_pref, retryable)
#    1439 """Internal retryable helper for all client transactions.
#    1440
#    1441 :Parameters:
#    (...)
#    1451   Output of the calling func()
#    1452 """
#    1453 return _ClientConnectionRetryable(
#    1454     mongo_client=self,
#    1455     func=func,
#    1456     bulk=bulk,
#    1457     is_read=is_read,
#    1458     session=session,
#    1459     read_pref=read_pref,
#    1460     address=address,
#    1461     retryable=retryable,
# -> 1462 ).run()
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymongo/mongo_client.py:2315, in _ClientConnectionRetryable.run(self)
#    2314 try:
# -> 2315     return self._read() if self._is_read else self._write()
#    2316 except ServerSelectionTimeoutError:
#    2317     # The application may think the write was never attempted
#    2318     # if we raise ServerSelectionTimeoutError on the retry
#    2319     # attempt. Raise the original exception instead.
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymongo/mongo_client.py:2439, in _ClientConnectionRetryable._read(self)
#    2438 assert self._read_pref is not None, "Read Preference required on read calls"
# -> 2439 with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#    2440     conn,
#    2441     read_pref,
#    2442 ):
#    2443     if self._retrying and not self._retryable:
#
# File /opt/homebrew/anaconda3/lib/python3.11/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymongo/mongo_client.py:1330, in MongoClient._conn_from_server(self, read_preference, server, session)
#    1328 single = topology.description.topology_type == TOPOLOGY_TYPE.Single
# -> 1330 with self._checkout(server, session) as conn:
#    1331     if single:
#
# File /opt/homebrew/anaconda3/lib/python3.11/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymongo/mongo_client.py:1252, in MongoClient._checkout(self, server, session)
#    1251     return
# -> 1252 with server.checkout(handler=err_handler) as conn:
#    1253     # Pin this session to the selected server or connection.
#    1254     if (
#    1255         in_txn
#    1256         and session
#    (...)
#    1261         )
#    1262     ):
#
# File /opt/homebrew/anaconda3/lib/python3.11/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymongo/pool.py:1637, in Pool.checkout(self, handler)
#    1635     listeners.publish_connection_check_out_started(self.address)
# -> 1637 conn = self._get_conn(handler=handler)
#    1639 if self.enabled_for_cmap:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymongo/pool.py:1756, in Pool._get_conn(self, handler)
#    1755 try:
# -> 1756     conn = self.connect(handler=handler)
#    1757 finally:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymongo/pool.py:1585, in Pool.connect(self, handler)
#    1584 try:
# -> 1585     sock = _configured_socket(self.address, self.opts)
#    1586 except BaseException as error:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymongo/pool.py:1296, in _configured_socket(address, options)
#    1295     details = _get_timeout_details(options)
# -> 1296     _raise_connection_failure(address, exc, "SSL handshake failed: ", timeout_details=details)
#    1297 if (
#    1298     ssl_context.verify_mode
#    1299     and not ssl_context.check_hostname
#    1300     and not options.tls_allow_invalid_hostnames
#    1301 ):
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pymongo/pool.py:403, in _raise_connection_failure(address, error, msg_prefix, timeout_details)
#     402 if isinstance(error, socket.timeout):
# --> 403     raise NetworkTimeout(msg) from error
#     404 elif isinstance(error, SSLError) and "timed out" in str(error):
#     405     # Eventlet does not distinguish TLS network timeouts from other
#     406     # SSLErrors (https://github.com/eventlet/eventlet/issues/692).
#     407     # Luckily, we can work around this limitation because the phrase
#     408     # 'timed out' appears in all the timeout related SSLErrors raised.
#
# NetworkTimeout: SSL handshake failed: ac-k1wg4ld-lb.7uzj7t2.mongodb.net:27017: timed out (configured timeouts: connectTimeoutMS: 20000.0ms)
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# /Users/abhijeetherra/Documents/USF/MSDS_697/waffle-iron/ml-pipeline-abhi.ipynb Cell 13 line 2
#       <a href='vscode-notebook-cell:/Users/abhijeetherra/Documents/USF/MSDS_697/waffle-iron/ml-pipeline-abhi.ipynb#X42sZmlsZQ%3D%3D?line=0'>1</a> uri = "mongodb+srv://waffleiron:zNkFSHTfTGroBXRq@waffleironcluster.7uzj7t2.mongodb.net/?retryWrites=true&w=majority&appName=WaffleIronCluster"
# ----> <a href='vscode-notebook-cell:/Users/abhijeetherra/Documents/USF/MSDS_697/waffle-iron/ml-pipeline-abhi.ipynb#X42sZmlsZQ%3D%3D?line=1'>2</a> data = deduplicate_and_aggregate(uri, "2024-03-01_cnn")
#       <a href='vscode-notebook-cell:/Users/abhijeetherra/Documents/USF/MSDS_697/waffle-iron/ml-pipeline-abhi.ipynb#X42sZmlsZQ%3D%3D?line=2'>3</a> data
#
# File ~/Documents/USF/MSDS_697/waffle-iron/aggregates_to_mongo.py:149, in deduplicate_and_aggregate(uri, sources_name)
#     147 except PyMongoError as e:
#     148     print(f"An error occurred: {e}")
# --> 149     return result
#
# UnboundLocalError: cannot access local variable 'result' where it is not associated with a value

# %%
data = list(data.find({}))
data
#pd.json_normalize(data, record_path=['articles'], meta=['_id', 'count'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[146], line 1
# ----> 1 data = list(data.find({}))
#       2 data
#
# AttributeError: 'CommandCursor' object has no attribute 'find'

# %%
import pandas as pd
def mongod_to_spark_date(data, sources_name):
    data = list(data.find({}))
    # print(data)
    new_data = pd.json_normalize(data, record_path=['articles'], meta=['count'])
    
    spark = SparkSession.builder \
        .appName("MongoDB to DataFrame") \
        .getOrCreate()

    new_data.to_csv('output.csv', index=False)
    df = spark.read.csv("output.csv", header=True, inferSchema=True)

    
    
    
    df.show()
    schema = StructType([
    StructField("_id", ObjectType(), nullable=True),
    StructField("title", ObjectType(), nullable=True),
    StructField("top_image", ObjectType(), nullable=True),
    StructField("url",ObjectType(), nullable=True),
    StructField("date", ObjectType(), nullable=True),
    StructField("short_description", StringType(), nullable=True),
    StructField("text", ObjectType(), nullable=True),
    StructField("convertedDate", ObjectType(), nullable=True),
    StructField("count", ObjectType(), nullable=True)
])
    df = spark.read.csv("output.csv", header=True, schema=schema)
    df.show()
    
    
    return df

# %%
# mongod_to_spark(data, "2024-03-01_cnn")

# %%
uri = "mongodb+srv://waffleiron:zNkFSHTfTGroBXRq@waffleironcluster.7uzj7t2.mongodb.net/?retryWrites=true&w=majority&appName=WaffleIronCluster"
data = data_from_mongob(uri, "cnn-date")
data
# Out:
# Collection(Database(MongoClient(host=['ac-k1wg4ld-lb.7uzj7t2.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='WaffleIronCluster', authsource='admin', loadbalanced=True, tls=True, server_api=<pymongo.server_api.ServerApi object at 0x113de4390>), 'news'), 'cnn-date')

# %%
data = list(data.find({}))
data
# Out:
# [{'_id': '2019-08-26',
#   'count': 1,
#   'articles': [{'_id': ObjectId('65e5131c4390593f61fbacf5'),
#     'title': 'G7 summit in Biarritz, France: Live updates',
#     'top_image': 'https://cdn.cnn.com/cnnnext/dam/assets/190826112137-07-trump-macron-g7-handshake-super-tease.jpg',
#     'url': 'https://news.google.com/rss/articles/CBMiS2h0dHBzOi8vd3d3LmNubi5jb20vcG9saXRpY3MvbGl2ZS1uZXdzL2c3LXN1bW1pdC1tb25kYXktZGxlLWludGwvaW5kZXguaHRtbNIBT2h0dHBzOi8vYW1wLmNubi5jb20vY25uL3BvbGl0aWNzL2xpdmUtbmV3cy9nNy1zdW1taXQtbW9uZGF5LWRsZS1pbnRsL2luZGV4Lmh0bWw?oc=5&hl=en-US&gl=US&ceid=US:en',
#     'date': '2019-08-26',
#     'short_description': 'Trump and world leaders meet at G7 summit: Live updates  CNN',
owers testified on Tuesday.\n\nThe second occurred several hours later, minutes before then-Vice President Mike Pence gaveled in the joint session of Congress to certify the electoral votes. According to text messages obtained by the committee, an aide to GOP Sen. Ron Johnson of Wisconsin asked an aide to Pence how Johnson could hand-deliver him the fake slates of Trump electors from Michigan and Wisconsin, which had not been sent to the National Archives. Pence\'s aide responded that Johnson should "not give that to him."\n\nBoth the effort to decertify Biden electors and put forward fake Trump electors were part of the Trump team\'s scheme to stop the congressional certification of the election on Jan. 6. The role that Trump\'s allies in Congress played have been of interest of interest to the committee, which has subpoenaed five House GOP members, including Biggs and House Minority Leader Kevin McCarthy.\n\nWitnesses describe how Trump\'s lies had serious consequences — including threats\n\nThe committee\'s hearing underscored how the lies about the election spread by Trump and his team spiraled into multi-faceted disasters for the state officials forced to grapple with them.\n\nAll of the witnesses who appeared at Tuesday\'s hearing talked about the serious repercussions they faced as a result of the false claims that Trump and his team put forward. That included pressure to help in the effort to ov ...
#     'convertedDate': datetime.datetime(2022, 6, 21, 0, 0)}]},
#  {'_id': '2020-11-05',
#   'count': 1,
#   'articles': [{'_id': ObjectId('65e5131c4390593f61fbad04'),
#     'title': 'Election 2020 presidential results',
#     'top_image': 'https://media.cnn.com/api/v1/images/stellar/prod/201030162605-04-trump-biden-election-night-split.jpg?q=x_0,y_0,h_619,w_1100,c_fill/w_800',
#     'url': 'https://edition.cnn.com/politics/live-news/election-results-and-news-11-04-20/index.html',
#     'date': '2020-11-05',
#     'short_description': 'The latest on election results: Live updates  CNN',
#     'text': 'President Trump’s team launched a series of lawsuits in key battleground states that seemed less about sound legal reasoning and more about slowing Joe Biden from marching over the electoral vote threshold.\n\nAt times, the lawsuits have contested ballots in the double digits — hundreds if not thousands of votes away of potentially swing any state’s result.\n\n“Admitting defeat is not a plausible reaction so soon after the election, so they throw a lot of Hail Mary lawsuits at the wall and hope something sticks,” said longtime Republican elections lawyer and CNN contributor Ben Ginsberg. He said these types of suits aren’t indicative of a campaign that’s feeling optimistic — and instead, is scrambling.\n\n“I think much of the litigation is a longshot and unlikely to succeed,” said Franita Tolson, a law professor at USC Gould School of Law and CNN contributor.\n\nShe pointed to a lawsuit in Georgia the Trump campaign announced Wednesday night over a poll worker mixing unprocessed and processed absentee ballots. That might have the potential to affect few votes, she said.\n\n“I suspect that a big goal of this litigation is, in the short term, to change the narrative” from a potential Biden win to a conversation about election mismanagement or even fraud, Tolson said.\n\nAnother law professor and CNN contributor, Rick Hasen, said the lawsuits appeared to be more public relations than serious litigation. “These lawsuits so far are not tackling any major problem that would seem to call overall vote totals into questions,” he said.\n\nJustin Levitt, another elections expert and law professor, called some of the suits, like in Michigan, “laughable.”\n\n“One says you didn’t put people by absentee dropboxes, so stop the count. Huh?!”\n\nEven a Republican-appointed federal judge in Pennsylvania cast doubt on the validity of a suit from Republicans on Wednesday, when they challenged fewer than 100 ballots that absentee voters corrected in a county outside Philadelphia. At a hearing Wednesday morning, the judge, Timothy Savage, did not rule, yet he suggested the lawyer for Republican canvass observers was seeking to disenfranchise votes. He noted the lawsuit appeared to have other problems in its arguments.\n\nSome legal challenges in Pennsylvania from the Trump campaign were quickly dismissed on Election Day, with Trump touting his appeals of those losses apparently as new cases Wednesday. For instance, a Philadelphia election day judge had shot down a Trump campaign case over ballot processing access, writing that “observers are directed only to observe and not to audit ballots” and deciding that the city’s board of elections complied with the law. Another Election Day challenge from the Trump campaign to the ballot observation process in Bucks County, Pennsylvania, also near Philly, was dismissed by a judge, though Trump is now appealing, according to Pennsylvania court records.\n\nLawyers for the Trump campaign sued in Nevada on Tuesday, too, claiming that their observers were not given enough access to all aspects of the ballot counting process — from opening the ballots, to machine and manual signature checking and duplicating spoiled ballots. A Nevada judge denied the GOP challenge to the early voting process in the heavily Democratic county.\n\n“If this last-minute suit were successful, it would require a major change in how [Nevada] processed absentee [ballots] to determine if the signature on the ballot matched the voter’s prior signature on file,” said Richard Pildes, a constitutional law professor at New York University and CNN election law analyst. “Courts are typically unwilling to let plaintiffs come in the door so late in the day and ask for major changes to a process that’s already well underway.”\n\nHowever, one suit, the petition before the US Supreme Court on Pennsylvania’s ballot deadline, may be a more serious litigation challenge. It challenges the validity of potentially several thousand votes cast in  ...
#     'convertedDate': datetime.datetime(2020, 11, 5, 0, 0)}]},
#  {'_id': '2023-08-14',
#   'count': 2,
#   'articles': [{'_id': ObjectId('65e5131c4390593f61fbacff'),
#     'title': 'Trump indicted in Georgia election probe by Fulton County grand jury',
#     'top_image': 'https://cdn.cnn.com/cnnnext/dam/assets/230808122319-05-donald-trump-072923-super-tease.jpg',
#     'url': 'https://edition.cnn.com/politics/live-news/trump-fulton-county-georgia-08-14-23/index.html',
#     'date': '2023-08-14',
#     'short_description': 'August 14, 2023 - Trump indicted in Georgia election probe by Fulton County grand jury  CNN',
#     'text': 'The most astonishing aspect of former President Donald Trump’s fourth criminal indictment is not the scale of an alleged multi-layered conspiracy to steal Georgia’s electoral votes in 2020 from their rightful winner.\n\nIt is that Trump – the accused kingpin of the scheme to overturn Joe Biden’s victory, who was charged on Monday along with 18 others – could in 17 months be raising his right hand as the 47th president and swearing to preserve, protect and defend the Constitution he was accused of plotting to shred.\n\nThe grave political crisis created by Trump’s aberrant presidency and subsequent efforts to hold him to account deepened significantly just before midnight with the unsealing of yet another indictment against him – this one from a grand jury in the critical swing state of Georgia.\n\nThe charges in this state case – which bring to 91 the total number of criminal charges he’s facing across four separate cases – intensified an already epochal collision between Trump’s now extreme legal quagmire and the 2024 election in which he is the front-runner for the Republican nomination.\n\nRead the full analysis here:',
#     'convertedDate': datetime.datetime(2023, 8, 14, 0, 0)},
#    {'_id': ObjectId('65e58494813b1284e12103a0'),
#     'title': 'Here are the names and titles of all 19 people charged in Georgia case',
#     'top_image': 'https://dynaimage.cdn.cnn.com/cnn/digital-images/org/cc00ca5c-dcd3-48a2-b600-018b0f2875ae.jpg',
#     'url': 'https://edition.cnn.com/politics/live-news/trump-fulton-county-georgia-08-14-23/h_c519d109a844b5c9932d605662e9066d',
#     'date': '2023-08-14',
#     'short_description': 'August 14, 2023 - Trump indicted in Georgia election probe by Fulton County grand jury  CNN',
#     'text': 'Hillary Clinton reacted to the news of the Georgia grand jury returning indictments in an interview on MSNBC Monday night.\n\n"Well, it\'s hard to believe, I don\'t feel any satisfaction. I feel great, you know, just great profound sadness that we have a former president who has been indicted for so many charges that went right to the heart of whether or not our democracy would survive," Clinton said.\n\n"We\'ll wait to see what the indictments themselves say because clearly this investigation has been very thorough, but I don\'t know that anybody should be satisfied," Clinton said. "This is a terrible moment for our country to have a former president accused of these terribly important crimes. The only satisfaction may be that the system is working. That all of the efforts by Donald Trump, his allies, and his enablers to try to silence the truth to try to undermine democracy have been brought into the light and justice is being pursued."\n\nSpeaking on holding Trump accountable, she said, "I hope that we won\'t have accountability just for Donald Trump and if there are others named in these indictments along with him for their behavior but we will also have accountability for a political party that has just thrown in with all the lies and the divisiveness and the lack of any conscience about what has been done to the country."\n\nWhile the grand jury hearing the Trump case has returned indictments, details of who may be charged are not yet known.',
#     'convertedDate': datetime.datetime(2023, 8, 14, 0, 0)}]},
#  {'_id': '2024-01-16',
#   'count': 2,
#   'articles': [{'_id': ObjectId('65e5131c4390593f61fbacfe'),
#     'title': 'How CNN made its projection that Trump has won the Iowa caucuses',
#     'top_image': 'https://dynaimage.cdn.cnn.com/cnn/digital-images/org/8b608f15-70ec-4640-b458-eed25e994eff.JPG',
#     'url': 'https://news.google.?oc=5&hl=en-US&gl=US&ceid=US:en',
#     'date': '2024-01-16',
#     'short_description': 'Live updates: The latest on the Iowa caucuses and 2024 primary campaign  CNN',
#     'text': "Former President Donald Trump speaks as he visits a caucus site at Horizon Event Center in Clive on Monday. Sergio Flores/Reuters\n\nFormer President Donald Trump will win the Iowa caucuses, CNN projected on Monday, solidifying his place as the front-runner for the 2024 Republican nomination.\n\nCNN’s projection was based on entrance polls conducted for the National Election Pool by Edison Research. These polls are carried out at a scientifically random sample of caucus sites across the state among voters who have shown up to participate.\n\nAs of 7 p.m. CT/8 p.m. ET, doors at caucus sites had closed and no one else would be allowed inside to participate, and entrance poll interviewing was complete.\n\nAt the time of CNN’s projection, at 7:30 p.m. CT/8:30 p.m. ET, the former president's broad lead in the entrance poll’s representative sample was statistically significant. By that time, votes had been reported in multiple counties and from several sample precincts, which also suggested a broad Trump lead.\n\nOther major national news organizations projected Trump as the winner at roughly the same time as CNN.",
#     'convertedDate': datetime.datetime(2024, 1, 16, 0, 0)},
#    {'_id': ObjectId('65e4447d396409552c7bfa65'),
#     'title': 'Trump wins Iowa caucuses, DeSantis finishes second ahead of Haley',
#     'top_image': 'https://cdn.cnn.com/cnnnext/dam/assets/240114114934-split-donald-trump-nikki-haley-ron-desantis-super-tease.jpg',
#     'url': 'https://edition.cnn.com/politics/live-news/iowa-caucuses-01-15-24#h_58774feb83e9a0d59e35709bbd746d09',
#     'date': '2024-01-16',
#     'short_description': 'Live updates: The latest on the Iowa caucuses and 2024 primary campaign  CNN',
mexico border — breaking with Trump\'s comments during the CNN town hall last month. The “zero tolerance” policy encapsulated the lengths Trump’s administration was willing to go to deter migrants from coming to the United States, and Trump said it remained a strong deterrent. “When you say to a family that if you come, we’re going to break you up, they don’t come,” Trump said during the town hall.\n\nAnd here are other key takeaways from the town hall:\n\nJustice Department investigations: Pence urged the Justice Department not to indict his onetime boss, saying such an indictment would fuel division inside the country and “send a terrible message to the wider world.” While Pence said that “no one is above the law,” he said the DOJ could resolve its investigation into Trump’s potential mishandling of classified documents without resorting to an indictment, just as the department informed Pence’s attorney last week that there would be no charges brought in the case of the classified documents discovered in his home.\n\nTransgender children: Pence repeatedly highlighted his support for “parents’ rights,” especially when it comes to schools. But he said the judgment of those same parents should not apply to situations when a minor is seeking gender transition care. “I strongly support state legislation, including, as we did in Indiana, that bans all gender transition, chemical or surgical procedures, under the age of 18,” he said – even when parents support their child’s decision to go forward.\n\nPro-life stance on abortion: Pence made clear he would not deviate from his anti-abortion position, saying, “We will not rest or relent until we restore the sanctity of life to the center of A ...
#     'convertedDate': datetime.datetime(2023, 6, 7, 0, 0)}]},
#  {'_id': '2024-02-14',
#   'count': 2,
#   'articles': [{'_id': ObjectId('65e2688011fa4540a0a38b21'),
#     'title': "House GOP's majority shrinks as Democrats flip Santos' New York seat",
#     'top_image': 'https://cdn.cnn.com/cnnnext/dam/assets/240213224502-dle-tom-suozzi-021324-super-tease.jpg',
#     'url': 'https://edition.cnn.com/politics/live-news/ny-special-election-santos-02-13-24/index.html',
#     'date': '2024-02-14',
#     'short_description': "House GOP's majority shrinks as Democrats flip Santos' New York seat  CNN",
#     'text': "Newly elected US House Speaker Mike Johnson speaks after his election at the US Capitol in Washington, DC, on October 25, 2023. Tom Brenner/AFP/Getty Images\n\nRepublican House Speaker Mike Johnson is overseeing one of the smallest House majorities in history – and Democrat Tom Suozzi’s win in a New York special election will shrink it further.\n\nSuozzi defeated Republican Mazi Pilip in a race for the seat previously held by former GOP Rep. George Santos who was expelled from Congress last year.\n\nWhen Suozzi is sworn in, Republicans will control 219 seats and Democrats will control 213. With a breakdown of 219 to 213, House Republicans will only be able to lose only two votes to pass legislation on party-line votes if all members are present and voting\n\nAfter the swearing in, there will be three vacancies in the House. Former New York Democratic Rep. Brian Higgins resigned from Congress earlier this month, former Ohio GOP Rep. Bill Johnson resigned last month and former Speaker Kevin McCarthy resigned at the end of last year.\n\nIn addition to the tight margin, there is always the possibility that absences could further impact the vote math. The razor-thin majority presents an enormous challenge for the speaker, leaving Johnson with almost no room for error as he navigates demands from competing wings of his party.\n\nHardline conservatives have already shown they can hold major sway in the chamber with such a narrow majority – most notably when a group of hardliners moved to oust McCarthy from the speakership in a historic vote last year.\n\nRead more about the House GOP's shrinking majority.",
#     'convertedDate': datetime.datetime(2024, 2, 14, 0, 0)},
#    {'_id': ObjectId('65e7b58a0c92d89c399d0161'),
#     'title': "CNN Projection: Democrat Tom Suozzi will win special election in New York's 3rd Congressional District",
#     'top_image': 'https://dynaimage.cdn.cnn.com/cnn/digital-images/org/927ac7cc-437f-40b6-8f5d-ca96c0354df0.jpg',
#     'convertedDate': datetime.datetime(2023, 4, 5, 0, 0)}]},
#  {'_id': '2022-11-09',
#   'count': 2,
#   'articles': [{'_id': ObjectId('65e5131c4390593f61fbacf1'),
#     'title': 'Live updates: 2022 midterm election results, livestream and voting day news - CNN',
#     'top_image': 'https://news.google.?oc=5&hl=en-US&gl=US&ceid=US:en/favicon.ico',
#     'url': 'https://news.google.?oc=5&hl=en-US&gl=US&ceid=US:en',
#     'date': '2022-11-09',
#     'short_description': 'Live updates: 2022 midterm election results, livestream and voting day news  CNN',
#     'text': 'Live updates: 2022 midterm election results, livestream and voting day news  CNN',
#     'convertedDate': datetime.datetime(2022, 11, 9, 0, 0)},
#    {'_id': ObjectId('65e7b58a0c92d89c399d016e'),
#     'title': 'CNN Projection: Democrat Alexandria Ocasio-Cortez will win reelection in New York’s 14th District',
#     'top_image': 'https://dynaimage.cdn.cnn.com/cnn/digital-images/org/9d89e887-ca93-49ef-af96-f09ac451bedc.jpg',
#     'url': 'https://news.google.?oc=5&hl=en-US&gl=US&ceid=US:en',
#     'date': '2022-11-09',
#     'short_description': 'Live updates: 2022 midterm election results, livestream and voting day news  CNN',
#     'text': "(Andrew Harnik/AP)\n\nSarah Huckabee Sanders, the one-time press secretary and communications director for former President Donald Trump, will win Arkansas’ gubernatorial race, CNN projects.\n\nShe will be the first woman elected governor of Arkansas.\n\nHuckabee Sanders defeated Democrat Chris Jones, who is a minister and former non-profit leader who got a degree in nuclear engineering from MIT.\n\nArkansas last elected a Democratic governor in 2010 and it’s now a solidly red state.\n\nSanders, while a first-time candidate, is no stranger to politics. Her father, Republican Mike Huckabee, was governor of Arkansas from 1996 to 2007. And by defeating Democrat Chris Jones, Sanders will also become the first daughter in US history to serve as governor of the same state her father once led.\n\nSanders previously worked for two years in the George W. Bush administration and later ran her father’s 2008 campaign for the Republican presidential nomination and then was campaign manager for his 2016 bid.\n\nShe gained national prominence in her role as former President Donald Trump’s White House press secretary, serving as a staunch defender of the then-President and his policies for more than two years. On many occasions, she clashed with national reporters and eventually scaled back televised briefings. She defended the move, saying that journalists could hear from Trump directly.\n\nSanders earned an early endorsement from Trump after joining the race for Arkansas governor, and prominent rivals later dropped out of the race, clearing her path to the GOP nomination.\n\nSanders’ path to victory in the race to succeed term-limited GOP Gov. Asa Hutchison was relatively smooth – unsurprising in a state that has taken a sharp turn to the right in recent years. But the campaign was not without personal challenges. In September, Sanders announced she was diagnosed with thyroid cancer and “underwent a successful surgery to remove my thyroid and surrounding lymph nodes.”\n\nIn her race for governor, Sanders defended her decision to grant only a handful of interviews with local media, saying she’s been speaking to voters directly.\n\n“Freedom of the press is incredibly important, but with freedom of the press also comes a great deal of responsibility, and when they don’t live up to their end of the bargain, it forces some of us to go outside of the box, which I have done every single day for the last two years,” Sanders said at an October 21 debate hosted by the Arkansas PBS station.\n\nIn the debate, Sanders highlighted key issues of her campaign, including her education plan, Arkansas LEARNS, to increase literacy rates, and her support for phasing out the state income tax, though she has not explicitly stated a timeline for doing so.\n\nCNN's Andrew Menezes contributed reporting to this post.",
# ...
#     'convertedDate': datetime.datetime(2024, 2, 28, 0, 0)},
#    {'_id': ObjectId('65e4447d396409552c7bfa44'),
#     'title': "Polls close at 8 p.m. ET across most of Michigan. Here's what to watch for in today's presidential primaries",
#     'top_image': 'https://dynaimage.cdn.cnn.com/cnn/digital-images/org/e39e9c2f-668b-4c05-b177-a5c1da774633.JPG',
#     'url': 'https://edition.cnn.com/politics/live-news/michigan-primary-02-27-24/h_2ecf5939681c41f107fb275ebb275e7e',
#     'date': '2024-02-28',
#     'short_description': 'Live updates: Michigan presidential primary election  CNN',
#     'text': "A man votes in Detroit on Tuesday. Dieu-Nalio Chery/Reuters\n\nPresident Joe Biden and former President Donald Trump are expected to win handily in their respective contests, but there will be lessons to learn for both.\n\nHere’s what to watch for in Michigan:\n\nThe first ballot test of Biden’s Israel strategy: Biden’s support for Israel – whose war in Gaza has killed roughly 30,000 Palestinians, according to the enclave's health ministry – has enraged American progressives, many of them Jewish, and Arab Americans. The Michigan city of Dearborn is home to one of the largest Arab American communities in the US. That anger is fueling a statewide movement among Democratic critics of Israel for voters to mark “uncommitted” on their ballots. Just how committed are Michigan Democrats to Biden? Tuesday will tell.\n\nA fractured and confusing GOP process: The split process of awarding delegates between a Michigan Republican primary on Tuesday and a state party convention on Saturday is the result of Republicans’ reaction to Democrats’ decision to shake up the party’s presidential nominating calendar after the 2020 election — demoting Iowa and New Hampshire, moving South Carolina and Nevada to the forefront and placing Michigan third in its new lineup.\n\nTests for Biden, Trump: Biden is banking on an endorsement from the United Auto Workers union, support from Black voters, and a stronger Democratic infrastructure — with an electorate energized by an abortion rights battle delivering Gov. Gretchen Whitmer and her party victories up and down the ballot in 2022. Trump, meanwhile, is hoping to re-engineer the White working-class coalition that helped him break down the “blue wall” of Pennsylvania, Michigan, and Wisconsin in 2016.\n\nRead more about what to look out for ahead of the Michigan presidential primaries.",
#     'convertedDate': datetime.datetime(2024, 2, 28, 0, 0)},
#    {'_id': ObjectId('65e7b58a0c92d89c399d012a'),
#     'title': 'Leaders of "Uncommitted" pledge to take anti-war movement to streets of Chicago',
#     'top_image': 'https://cdn.cnn.com/cnnnext/dam/assets/230917171655-trump-biden-split-0917-super-tease.jpg',
#     'url': 'https://news.google.com/rss/articles/CBMiY2h0dHBzOi8vd3d3LmNubi5jb20vcG9saXRpY3MvbGl2ZS1uZXdzL21pY2hpZ2FuLXByaW1hcnktMDItMjctMjQvaF8yMTI3YzM0YzExZWViYWNiZmVmMDQ1YjNjYmQ4YzUyONIBAA?oc=5&hl=en-US&gl=US&ceid=US:en',
#     'date': '2024-02-28',
#     'short_description': '(1) Leaders of "Uncommitted" pledge to take anti-war movement to streets of Chicago  CNN',
with orders to preserve these records so users can't delete them. That means getting subpoenas and search warrants for the contents of that chatroom. That takes some time because you have to show probable cause. The FBI was able to convince a reluctant witness who was a member of the chat group to cooperate and that helped move this process forward\n\nThe Washington Post was able to exploit that end of the case and talk to a member of the chat group who wouldn’t name the leader who posted the documents. The New York Times published his name before he was arrested, but that’s reporting, not evidence.\n\nThe DOD, FBI and OSI, the Air Force Office of Special Investigations explored those same paths, but they also did things reporters and online gamers and sleuths couldn’t do — they pulled logs. Who looked at those documents? Who, in a classified setting, read those reports and then sent them to a classified printer that logs every document it prints with a time stamp and the computer that sent the request. The computer records the chip of the ID card ...
#     'convertedDate': datetime.datetime(2023, 4, 13, 0, 0)}]},
#  {'_id': '2024-01-17',
#   'count': 1,
#   'articles': [{'_id': ObjectId('65e5131c4390593f61fbace4'),
#     'title': 'E. Jean Carroll defamation trial against Donald Trump',
#     'top_image': 'https://cdn.cnn.com/cnnnext/dam/assets/230509062547-donald-trump-e-jean-carroll-split--super-tease.jpg',
#     'url': 'https://edition.cnn.com/politics/live-news/trump-defamation-trial-e-jean-carroll-01-17-24/index.html',
#     'date': '2024-01-17',
#     'short_description': "January 17 - Trump's trial in E. Jean Carroll defamation case  CNN",
#     'text': 'Donald Trump clashed in court Wednesday with yet another judge overseeing one of his trials – after the judge in his civil defamation case threatened to remove the former president for making comments that could be overheard by the jury while his accuser was testifying.\n\nThe exchange with Judge Lewis Kaplan was merely the latest in a string of Trump’s in-court fights during two civil trials in New York over the past several months, offering a preview of what’s to come if any of the former president’s criminal trials are held this year as he runs for president.\n\nMeanwhile, on the witness stand, E. Jean Carroll told the jury how Trump’s statements after she went public about him allegedly sexually assaulting her shattered her reputation and led to an onslaught of threatening messages. A civil jury last year found Carroll’s allegations to be credible.\n\n“I thought I was going to get shot,” she said.\n\nCarroll will return on the stand Thursday morning as Trump attorney Alina Habba finishes her cross-examination.\n\nThe former president is not expected to be there watching, as Trump plans to travel to Florida for his mother-in-law’s funeral, and Kaplan declined to postpone the trial in his absence at Trump’s request again on Wednesday.\n\nHere’s what to know from Wednesday’s court session:',
#     'convertedDate': datetime.datetime(2024, 1, 17, 0, 0)}]},
#  {'_id': '2023-10-01',
#   'count': 1,
#   'articles': [{'_id': ObjectId('65e5131c4390593f61fbacf0'),
#     'title': 'Highlights: US averts government shutdown',
#     'top_image': 'https://cdn.cnn.com/cnnnext/dam/assets/230929150450-01-us-capitol-red-light-093021-super-tease.jpg',
#     'url': 'https://news.google.?oc=5&hl=en-US&gl=US&ceid=US:en',
#     'date': '2023-10-01',
#     'short_description': 'US averts government shutdown  CNN',
#     'text': 'A government shutdown was prevented after Congress passed a stopgap funding measure ahead of a critical midnight deadline in a whirlwind day on Capitol Hill.\n\nPresident Joe Biden signed the bill late Saturday night.\n\nCatch up here:\n\nHow it came together: House Speaker Kevin McCarthy announced the stopgap proposal Saturday morning, a move that came after weeks of infighting among House Republicans and a failed effort to pass a GOP stopgap bill in the chamber. The bill passed the House with an overwhelmingly bipartisan vote, and it then was sent to the Senate. The final vote was 88 to 9.\n\nThe bill will keep the government open through November 17 and includes natural disaster aid but not additional funding for Ukraine or border security.\n\nConcerns over Ukraine funding: The stopgap bill originally included funding for Ukraine to help Kyiv fight the full-scale invasion from Russia, but the funds were dropped after some conservatives raised objections during negotiations.\n\nDemocratic Colorado Sen. Michael Bennet briefly held up the vote on the bill after he objected over concerns about the lack of funding in it. Bipartisan members of Senate leadership released a joint statement committing to vote on further funding for Ukraine aid "in the coming weeks."\n\nHouse Democratic leadership said in a statement that they expect McCarthy to bring a separate Ukraine aid bill to vote when the House returns.\n\n“We cannot under any circumstances allow American support for Ukraine to be interrupted,” Biden said in a statement.\n\nMcCarthy\'s fate unknown: The decision by McCarthy to put a bill on the floor that would win support from Democrats could put his speakership at risk as hardline conservatives continue to threaten a vote to oust him from the top House leadership post.\n\nMcCarthy was defiant after the vote, daring his detractors to try to push him out as he argued he did what was needed to govern effectively.\n\n“If somebody wants to make a motion against me, bring it,” McCarthy told CNN’s Manu Raju at a news conference. “There has to be an adult in the room. I am going to govern with what’s best for this country.”\n\nHardliners are expected to force a vote to remove McCarthy as speaker, just “not yet,” according to a Republican lawmaker.\n\nFire alarm incident: New York Rep. Jamaal Bowman pulled a fire alarm in a House office building on Saturday morning shortly before the House was scheduled to vote on the funding bill, which he said was an accident.\n\n“I was trying to get to a door. I thought the alarm would open the door, and I pulled the fire alarm to open the door by accident,” he told reporters.\n\n“I was just trying to get to my vote, and the door that’s usually open wasn’t open, it was closed,” Bowman added.\n\nHouse Administration Committee Chair Bryan Steil, who first revealed the incident, said "an investigation into why it was pulled is underway."\n\nMcCarthy said the House ethics committee should look into it, while GOP Rep. Lisa McClain told CNN that she was circulating a resolution to censure Bowman.',
#     'convertedDate': datetime.datetime(2023, 10, 1, 0, 0)}]}]

# %%
df = pd.json_normalize(data, record_path=['articles'], meta=['count'])
df = df.astype(str)
df.to_csv('game.csv', index=False)
df.dtypes
# Out:
# _id                  object
# title                object
# top_image            object
# url                  object
# date                 object
# short_description    object
# text                 object
# convertedDate        object
# count                object
# dtype: object

# %%
spark = SparkSession.builder \
        .appName("MongoDB to DataFrame") \
        .getOrCreate()
schema = StructType([
    StructField("_id", StringType(), nullable=True),
    StructField("title", StringType(), nullable=True),
    StructField("top_image", StringType(), nullable=True),
    StructField("url", StringType(), nullable=True),
    StructField("date", StringType(), nullable=True),
    StructField("short_description", StringType(), nullable=True),
    StructField("text", StringType(), nullable=True),
    StructField("convertedDate", TimestampType(), nullable=True),
    StructField("count", IntegerType(), nullable=True)
])
df = spark.read.csv("game.csv", header=True, schema=schema)
df.show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------+-----+
# |                 _id|               title|           top_image|                 url|                date|   short_description|                text|convertedDate|count|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------+-----+
# |65e5131c4390593f6...|G7 summit in Biar...|https://cdn.cnn.c...|https://news.goog...|          2019-08-26|Trump and world l...|"President Trump,...|         NULL| NULL|
# |A reporter asked ...| ""What do you th...|                NULL|                NULL|                NULL|                NULL|                NULL|         NULL| NULL|
# |Trump said the US...|                NULL|                NULL|                NULL|                NULL|                NULL|                NULL|         NULL| NULL|
# |""I feel that the...|"" he said. ""And...| which frankly ar...|                NULL|                NULL|                NULL|                NULL|         NULL| NULL|
# |Trump said that w...| he see himself a...|                NULL|                NULL|                NULL|                NULL|                NULL|         NULL| NULL|
# |""I want the clea...|         "" he said.|                NULL|                NULL|                NULL|                NULL|                NULL|         NULL| NULL|
# |""I think I know ...| with pensions an...|                NULL|                NULL|                NULL|                NULL|                NULL|         NULL| NULL|
# |Some context: Ear...| Trump skipped a ...|                NULL|                NULL|                NULL|                NULL|                NULL|         NULL| NULL|
# |In the lead-up to...| Trump's aides sa...| believing them a...|                NULL|                NULL|                NULL|                NULL|         NULL| NULL|
# |      After past G7s| Trump complained...| like clearing oc...|          2019-08-26|                   1|                NULL|                NULL|         NULL| NULL|
# |65e5131c4390593f6...|Here's what to wa...|https://dynaimage...|https://edition.c...|          2024-01-18|Live updates: Nik...|The stage is set ...|         NULL| NULL|
# |Nikki Haley is se...| just days before...|                NULL|                NULL|                NULL|                NULL|                NULL|         NULL| NULL|
# |Haley’s campaign ...| whose campaign i...| has escalated hi...|                NULL|                NULL|                NULL|                NULL|         NULL| NULL|
# |Here are a few th...|                NULL|                NULL|                NULL|                NULL|                NULL|                NULL|         NULL| NULL|
# |Haley will need t...| but how? Wary of...| Haley in recent ...|                NULL|                NULL|                NULL|                NULL|         NULL| NULL|
# |Wary of alienatin...| Haley in recent ...| Trump slammed Ha...| Nimarata — which...| and is a US citi...|                NULL|                NULL|         NULL| NULL|
# |In a post Tuesday...| Trump slammed Ha...| Nimarata — which...| and is a US citi...| what about South...| South Carolina’s...| polls show Trump...|         NULL| NULL|
# |Read up on more t...|          2024-01-18|                   1|                NULL|                NULL|                NULL|                NULL|         NULL| NULL|
# |65e66758f96774f41...|Jan 6 hearings da...|https://cdn.cnn.c...|https://news.goog...|          2022-06-21|Jan. 6 hearings d...|An audio recordin...|         NULL| NULL|
# |The latest hearin...|                NULL|                NULL|                NULL|                NULL|                NULL|                NULL|         NULL| NULL|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------+-----+
# only showing top 20 rows

# %%
uri = "mongodb+srv://waffleiron:zNkFSHTfTGroBXRq@waffleironcluster.7uzj7t2.mongodb.net/?retryWrites=true&w=majority&appName=WaffleIronCluster"
data = data_from_mongob(uri, "cnn-date")
data
csvs = mongod_to_spark_date(data, "cnn-date")
csvs.show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |                 _id|               title|           top_image|                 url|                date|   short_description|                text|       convertedDate|count|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |65e5131c4390593f6...|G7 summit in Biar...|https://cdn.cnn.c...|https://news.goog...|          2019-08-26|Trump and world l...|"President Trump,...|                NULL| NULL|
# |A reporter asked ...| ""What do you th...|                NULL|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|
# |Trump said the US...|                NULL|                NULL|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|
# |""I feel that the...|"" he said. ""And...| which frankly ar...|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|
# |Trump said that w...| he see himself a...|                NULL|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|
# |""I want the clea...|         "" he said.|                NULL|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|
# |""I think I know ...| with pensions an...|                NULL|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|
# |Some context: Ear...| Trump skipped a ...|                NULL|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|
# |In the lead-up to...| Trump's aides sa...| believing them a...|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|
# |      After past G7s| Trump complained...| like clearing oc...|          2019-08-26|                   1|                NULL|                NULL|                NULL| NULL|
# |65e5131c4390593f6...|Here's what to wa...|https://dynaimage...|https://edition.c...|          2024-01-18|Live updates: Nik...|The stage is set ...|                NULL| NULL|
# |Nikki Haley is se...| just days before...|                NULL|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|
# |Haley’s campaign ...| whose campaign i...| has escalated hi...|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|
# |Here are a few th...|                NULL|                NULL|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|
# |Haley will need t...| but how? Wary of...| Haley in recent ...|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|
# |Wary of alienatin...| Haley in recent ...| Trump slammed Ha...| Nimarata — which...| and is a US citi...|                NULL|                NULL|                NULL| NULL|
# |In a post Tuesday...| Trump slammed Ha...| Nimarata — which...| and is a US citi...| what about South...| South Carolina’s...| polls show Trump...| all eyes would b...| NULL|
# |Read up on more t...|          2024-01-18|                   1|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|
# |65e66758f96774f41...|Jan 6 hearings da...|https://cdn.cnn.c...|https://news.goog...|          2022-06-21|Jan. 6 hearings d...|An audio recordin...|                NULL| NULL|
# |The latest hearin...|                NULL|                NULL|                NULL|                NULL|                NULL|                NULL|                NULL| NULL|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# only showing top 20 rows
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[204], line 4
#       2 data = data_from_mongob(uri, "cnn-date")
#       3 data
# ----> 4 csvs = mongod_to_spark_date(data, "cnn-date")
#       5 csvs.show()
#
# Cell In[198], line 19, in mongod_to_spark_date(data, sources_name)
#      12     df = spark.read.csv("output.csv", header=True, inferSchema=True)
#      17     df.show()
#      18     schema = StructType([
# ---> 19     StructField("_id", ObjectType(), nullable=True),
#      20     StructField("title", ObjectType(), nullable=True),
#      21     StructField("top_image", ObjectType(), nullable=True),
#      22     StructField("url",ObjectType(), nullable=True),
#      23     StructField("date", ObjectType(), nullable=True),
#      24     StructField("short_description", StringType(), nullable=True),
#      25     StructField("text", ObjectType(), nullable=True),
#      26     StructField("convertedDate", ObjectType(), nullable=True),
#      27     StructField("count", ObjectType(), nullable=True)
#      28 ])
#      29     df = spark.read.csv("output.csv", header=True, schema=schema)
#      30     df.show()
#
# NameError: name 'ObjectType' is not defined

# %%
csvs["articles"][0].replace('"', "'")

# %%
import json

# Given string representation of JSON
json_string = csvs["articles"][0]

# Replace invalid characters
json_string = json_string.replace("’", "'")

# Replace single quotes with double quotes for property names
json_string = json_string.replace("'", '"').replace("ObjectId", "").replace("datetime.datetime", "").replace("(", "[").replace(")", "]")

# Convert the string to a Python object
python_object = json.loads(json_string)

# Convert the Python object back to JSON
#json_object = json.dumps(python_object)

#print(json_object)


json_string
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[205], line 4
#       1 import json
#       3 # Given string representation of JSON
# ----> 4 json_string = csvs["articles"][0]
#       6 # Replace invalid characters
#       7 json_string = json_string.replace("’", "'")
#
# File ~/anaconda3/envs/DistributedComputing/lib/python3.11/site-packages/pyspark/sql/dataframe.py:3078, in DataFrame.__getitem__(self, item)
#    3006 """Returns the column as a :class:`Column`.
#    3007
#    3008 .. versionadded:: 1.3.0
#    (...)
#    3075 +---+----+
#    3076 """
#    3077 if isinstance(item, str):
# -> 3078     jc = self._jdf.apply(item)
#    3079     return Column(jc)
#    3080 elif isinstance(item, Column):
#
# File ~/anaconda3/envs/DistributedComputing/lib/python3.11/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File ~/anaconda3/envs/DistributedComputing/lib/python3.11/site-packages/pyspark/errors/exceptions/captured.py:185, in capture_sql_exception.<locals>.deco(*a, **kw)
#     181 converted = convert_exception(e.java_exception)
#     182 if not isinstance(converted, UnknownException):
#     183     # Hide where the exception came from that shows a non-Pythonic
#     184     # JVM exception message.
# --> 185     raise converted from None
#     186 else:
#     187     raise
#
# AnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `articles` cannot be resolved. Did you mean one of the following? [`_id`, `title`, `top_image`, `url`, `date`, `short_description`, `text`, `convertedDate`, `count`].

# %%
import json

# Given string representation of JSON
json_string = "[{'_id': ObjectId('65e5131c4390593f61fbacf5'), 'title': 'G7 summit in Biarritz, France: Live updates', 'top_image': 'https://cdn.cnn.com/cnnnext/dam/assets/190826112137-07-trump-macron-g7-handshake-super-tease.jpg', 'url': 'https://news.google.com/rss/articles/CBMiS2h0dHBzOi8vd3d3LmNubi5jb20vcG9saXRpY3MvbGl2ZS1uZXdzL2c3LXN1bW1pdC1tb25kYXktZGxlLWludGwvaW5kZXguaHRtbNIBT2h0dHBzOi8vYW1wLmNubi5jb20vY25uL3BvbGl0aWNzL2xpdmUtbmV3cy9nNy1zdW1taXQtbW9uZGF5LWRsZS1pbnRsL2luZGV4Lmh0bWw?oc=5&hl=en-US&gl=US&ceid=US:en', 'date': '2019-08-26', 'short_description': 'Trump and world leaders meet at G7 summit: Live updates  CNN', 'text': 'President Trump, when asked about the climate crisis, said he wants clean air and clean water — but also wants the US to hold onto its 'tremendous wealth.'\\n\\nA reporter asked Trump, 'What do you think the world should be doing about climate change and do you still harbor that skepticism?'\\n\\nTrump said the US has become 'the No. 1 energy producer in the world.'\\n\\n'I feel that the United States has tremendous wealth. The wealth is under its feet. I’ve made that wealth come alive,' he said. 'And I’m not going to lose that wealth. I’m not going to lose it on dreams — on windmills, which frankly aren’t working too well. ”\\n\\nTrump said that while he wanted to continue energy production, he see himself as an environmentalist.\\n\\n'I want the cleanest water on Earth. I want the cleanest air on Earth. And that’s what we’re doing. And I’m an environmentalist,' he said.\\n\\n'I think I know more about the environment than most people. I want clean air. I want clean water. I want a wealthy country. I want a spectacular country with jobs, with pensions and so many things and that’s what we’re getting.'\\n\\nSome context: Earlier today, Trump skipped a session devoted to climate change at the G7 summit.\\n\\nIn the lead-up to the G7, Trump\\'s aides said he wasn\\'t entirely interested in the climate portions of the summit, believing them a waste of time compared to discussion of the economy.\\n\\nAfter past G7s, Trump complained that too much time was spent on issues he deemed unimportant, like clearing oceans of plastics.', 'convertedDate': datetime.datetime(2019, 8, 26, 0, 0)}]"

# Replace single quotes with double quotes and load as JSON
json_object = json.loads(csvs["articles"][0].replace('"', "'").replace("'", '"'))

print(json_object)
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[206], line 7
#       4 json_string = "[{'_id': ObjectId('65e5131c4390593f61fbacf5'), 'title': 'G7 summit in Biarritz, France: Live updates', 'top_image': 'https://cdn.cnn.com/cnnnext/dam/assets/190826112137-07-trump-macron-g7-handshake-super-tease.jpg', 'url': 'https://news.google.com/rss/articles/CBMiS2h0dHBzOi8vd3d3LmNubi5jb20vcG9saXRpY3MvbGl2ZS1uZXdzL2c3LXN1bW1pdC1tb25kYXktZGxlLWludGwvaW5kZXguaHRtbNIBT2h0dHBzOi8vYW1wLmNubi5jb20vY25uL3BvbGl0aWNzL2xpdmUtbmV3cy9nNy1zdW1taXQtbW9uZGF5LWRsZS1pbnRsL2luZGV4Lmh0bWw?oc=5&hl=en-US&gl=US&ceid=US:en', 'date': '2019-08-26', 'short_description': 'Trump and world leaders meet at G7 summit: Live updates  CNN', 'text': 'President Trump, when asked about the climate crisis, said he wants clean air and clean water — but also wants the US to hold onto its 'tremendous wealth.'\\n\\nA reporter asked Trump, 'What do you think the world should be doing about climate change and do you still harbor that skepticism?'\\n\\nTrump said the US has become 'the No. 1 energy producer in the world.'\\n\\n'I feel that the United States has tremendous wealth. The wealth is under its feet. I’ve made that wealth come alive,' he said. 'And I’m not going to lose that wealth. I’m not going to lose it on dreams — on windmills, which frankly aren’t working too well. ”\\n\\nTrump said that while he wanted to continue energy production, he see himself as an environmentalist.\\n\\n'I want the cleanest water on Earth. I want the cleanest air on Earth. And that’s what we’re doing. And I’m an environmentalist,' he said.\\n\\n'I think I know more about the environment than most people. I want clean air. I want clean water. I want a wealthy country. I want a spectacular country with jobs, with pensions and so many things and that’s what we’re getting.'\\n\\nSome context: Earlier today, Trump skipped a session devoted to climate change at the G7 summit.\\n\\nIn the lead-up to the G7, Trump\\'s aides said he wasn\\'t entirely interested in the climate portions of the summit, believing them a waste of time compared to discussion of the economy.\\n\\nAfter past G7s, Trump complained that too much time was spent on issues he deemed unimportant, like clearing oceans of plastics.', 'convertedDate': datetime.datetime(2019, 8, 26, 0, 0)}]"
#       6 # Replace single quotes with double quotes and load as JSON
# ----> 7 json_object = json.loads(csvs["articles"][0].replace('"', "'").replace("'", '"'))
#       9 print(json_object)
#
# File ~/anaconda3/envs/DistributedComputing/lib/python3.11/site-packages/pyspark/sql/dataframe.py:3078, in DataFrame.__getitem__(self, item)
#    3006 """Returns the column as a :class:`Column`.
#    3007
#    3008 .. versionadded:: 1.3.0
#    (...)
#    3075 +---+----+
#    3076 """
#    3077 if isinstance(item, str):
# -> 3078     jc = self._jdf.apply(item)
#    3079     return Column(jc)
#    3080 elif isinstance(item, Column):
#
# File ~/anaconda3/envs/DistributedComputing/lib/python3.11/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File ~/anaconda3/envs/DistributedComputing/lib/python3.11/site-packages/pyspark/errors/exceptions/captured.py:185, in capture_sql_exception.<locals>.deco(*a, **kw)
#     181 converted = convert_exception(e.java_exception)
#     182 if not isinstance(converted, UnknownException):
#     183     # Hide where the exception came from that shows a non-Pythonic
#     184     # JVM exception message.
# --> 185     raise converted from None
#     186 else:
#     187     raise
#
# AnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `articles` cannot be resolved. Did you mean one of the following? [`_id`, `title`, `top_image`, `url`, `date`, `short_description`, `text`, `convertedDate`, `count`].

# %%
import json
import csv
import ast

# The given string representation of JSON
json_string = csvs["articles"][0].replace('"', "'").replace("'", '"')

#json_string = ast.literal_eval(json_string)

# Convert the string to a Python object (list of dictionaries)
data_list = json.loads(json_string.replace("ObjectId", "").replace("datetime.datetime", "").replace("(", "[").replace(")", "]"))

# Extract field names
field_names = list(data_list[0].keys())

# Write data to CSV file
with open('data.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=field_names)
    
    # Write header
    writer.writeheader()
    
    # Write data
    writer.writerows(data_list)

print("CSV file created successfully.")
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[73], line 11
#       6 json_string = csvs["articles"][0].replace('"', "'").replace("'", '"')
#       8 #json_string = ast.literal_eval(json_string)
#       9
#      10 # Convert the string to a Python object (list of dictionaries)
# ---> 11 data_list = json.loads(json_string.replace("ObjectId", "").replace("datetime.datetime", "").replace("(", "[").replace(")", "]"))
#      13 # Extract field names
#      14 field_names = list(data_list[0].keys())
#
# File ~/anaconda3/envs/DistributedComputing/lib/python3.11/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~/anaconda3/envs/DistributedComputing/lib/python3.11/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~/anaconda3/envs/DistributedComputing/lib/python3.11/json/decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)
#     350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting ',' delimiter: line 1 column 755 (char 754)

# %%
# The given string representation of JSON
def json_string_to_csv(json_string):
    # Convert the string to a Python object (list of dictionaries)
    print(type(json_string))
    json_string = json_string.replace('"', "'").replace("'", '"')
    data_list = json.loads(json_string.replace("ObjectId", "").replace("datetime.datetime", "").replace("(", "[").replace(")", "]"))
    csv_filename = "test.csv"
    # Extract field names
    field_names = list(data_list[0].keys())

    # Write data to CSV file
    with open(csv_filename, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=field_names)
        
        # Write header
        writer.writeheader()
        
        # Write data
        writer.writerows(data_list)

    print("CSV file created successfully.")

    # Read CSV file into DataFrame
    dfs = pd.read_csv(csv_filename)

    # Clean DataFrame
    dfs = dfs.drop(columns=["videos", "images"])
    dfs["publisher"] = dfs["publisher"].apply(lambda x: eval(x)['title'])

    return dfs
json_string_to_csv("[{'_id': ObjectId('65e5131c4390593f61fbad02'), 'title': 'The 2020 Iowa caucuses: Live updates - CNN', 'top_image': 'news.google.com/favicon.ico', 'images': [], 'videos': [], 'url': 'https://news.google.?oc=5&hl=en-US&gl=US&ceid=US:en', 'date': '2020-02-05', 'short_description': 'The 2020 Iowa caucuses: Live updates  CNN', 'text': 'The 2020 Iowa caucuses: Live updates  CNN', 'publisher': {'href': 'https://www.cnn.com', 'title': 'CNN'}, 'convertedDate': datetime.datetime(2020, 2, 5, 0, 0)}]")
# Out:
# <class 'str'>
# CSV file created successfully.
#                             _id                                       title  \
# 0  ['65e5131c4390593f61fbad02']  The 2020 Iowa caucuses: Live updates - CNN
#
#                      top_image  \
# 0  news.google.com/favicon.ico
#
#                                                  url        date  \
# 0  https://news.google.com/rss/articles/CBMiWmh0d...  2020-02-05
#
#                            short_description  \
# 0  The 2020 Iowa caucuses: Live updates  CNN
#
#                                         text publisher       convertedDate
# 0  The 2020 Iowa caucuses: Live updates  CNN       CNN  [2020, 2, 5, 0, 0]

# %%
csvs["articles"].apply(json_string_to_csv)
# Out:
# <class 'str'>
# CSV file created successfully.
# <class 'str'>
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 csvs["articles"].apply(json_string_to_csv)
#
# File ~/anaconda3/envs/DistributedComputing/lib/python3.11/site-packages/pandas/core/series.py:4630, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4520 def apply(
#    4521     self,
#    4522     func: AggFuncType,
#    (...)
#    4525     **kwargs,
#    4526 ) -> DataFrame | Series:
#    4527     """
#    4528     Invoke function on values of Series.
#    4529
#    (...)
#    4628     dtype: float64
#    4629     """
# -> 4630     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/anaconda3/envs/DistributedComputing/lib/python3.11/site-packages/pandas/core/apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# File ~/anaconda3/envs/DistributedComputing/lib/python3.11/site-packages/pandas/core/apply.py:1076, in SeriesApply.apply_standard(self)
#    1074     else:
#    1075         values = obj.astype(object)._values
# -> 1076         mapped = lib.map_infer(
#    1077             values,
#    1078             f,
#    1079             convert=self.convert_dtype,
#    1080         )
#    1082 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1083     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1084     #  See also GH#25959 regarding EA support
#    1085     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/anaconda3/envs/DistributedComputing/lib/python3.11/site-packages/pandas/_libs/lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# Cell In[62], line 6, in json_string_to_csv(json_string)
#       4 print(type(json_string))
#       5 json_string = json_string.replace('"', "'").replace("'", '"')
# ----> 6 data_list = json.loads(json_string.replace("ObjectId", "").replace("datetime.datetime", "").replace("(", "[").replace(")", "]"))
#       7 csv_filename = "test.csv"
#       8 # Extract field names
#
# File ~/anaconda3/envs/DistributedComputing/lib/python3.11/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~/anaconda3/envs/DistributedComputing/lib/python3.11/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~/anaconda3/envs/DistributedComputing/lib/python3.11/json/decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)
#     350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting ',' delimiter: line 1 column 1801 (char 1800)

# %%
json_strings = csvs["articles"]

# Fix the JSON string by replacing single quotes with double quotes
json_strings_fixed = json_strings.replace("'", '"')

# Convert the JSON string to a Python object (list of dictionaries)
data_list = json.loads(json_strings_fixed)

# Convert the Python object to JSON
json_data = json.dumps(data_list)

print(json_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 7
#       4 json_strings_fixed = json_strings.replace("'", '"')
#       6 # Convert the JSON string to a Python object (list of dictionaries)
# ----> 7 data_list = json.loads(json_strings_fixed)
#       9 # Convert the Python object to JSON
#      10 json_data = json.dumps(data_list)
#
# File ~/anaconda3/envs/DistributedComputing/lib/python3.11/json/__init__.py:339, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337 else:
#     338     if not isinstance(s, (bytes, bytearray)):
# --> 339         raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     340                         f'not {s.__class__.__name__}')
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
#
# TypeError: the JSON object must be str, bytes or bytearray, not Series

# %%
import json

json_strings = csvs["articles"].apply(eval)
json_strings

#data_list = eval(json_strings)

# Convert the Python object to JSON
#json_data = json.dumps(data_list)

#print(json_data)#
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 import json
# ----> 3 json_strings = csvs["articles"].apply(eval)
#       4 json_strings
#
# File ~/anaconda3/envs/DistributedComputing/lib/python3.11/site-packages/pandas/core/series.py:4630, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4520 def apply(
#    4521     self,
#    4522     func: AggFuncType,
#    (...)
#    4525     **kwargs,
#    4526 ) -> DataFrame | Series:
#    4527     """
#    4528     Invoke function on values of Series.
#    4529
#    (...)
#    4628     dtype: float64
#    4629     """
# -> 4630     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/anaconda3/envs/DistributedComputing/lib/python3.11/site-packages/pandas/core/apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# File ~/anaconda3/envs/DistributedComputing/lib/python3.11/site-packages/pandas/core/apply.py:1076, in SeriesApply.apply_standard(self)
#    1074     else:
#    1075         values = obj.astype(object)._values
# -> 1076         mapped = lib.map_infer(
#    1077             values,
#    1078             f,
#    1079             convert=self.convert_dtype,
#    1080         )
#    1082 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1083     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1084     #  See also GH#25959 regarding EA support
#    1085     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/anaconda3/envs/DistributedComputing/lib/python3.11/site-packages/pandas/_libs/lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# File <string>:1
#
# NameError: name 'ObjectId' is not defined

# %%
json_strings[0] #.keys()
# Out:
# "[{'_id': ObjectId('65e5131c4390593f61fbad02'), 'title': 'The 2020 Iowa caucuses: Live updates - CNN', 'top_image': 'news.google.com/favicon.ico', 'images': [], 'videos': [], 'url': 'https://news.google.?oc=5&hl=en-US&gl=US&ceid=US:en', 'date': '2020-02-05', 'short_description': 'The 2020 Iowa caucuses: Live updates  CNN', 'text': 'The 2020 Iowa caucuses: Live updates  CNN', 'publisher': {'href': 'https://www.cnn.com', 'title': 'CNN'}, 'convertedDate': datetime.datetime(2020, 2, 5, 0, 0)}]"

# %%
from pyspark.sql.functions import explode
from pyspark.sql.functions import from_json
from pyspark.sql.types import StructType, StructField, StringType, MapType
from pyspark.sql.functions import concat_ws
spark = SparkSession.builder \
        .appName("MongoDB to DataFrame") \
        .getOrCreate()
schema = StructType([
    StructField("_id", StringType(), True),
    StructField("count", IntegerType(), True),
    StructField("articles", ArrayType(StringType()), True)
])

df = spark.createDataFrame(csv, schema)

schema = StructType([
    StructField("_id", StringType(), nullable=False),
    StructField("title", StringType(), nullable=True),
    StructField("top_image", StringType(), nullable=True),
    StructField("images", ArrayType(StringType()), nullable=True),
    StructField("videos", ArrayType(StringType()), nullable=True),
    StructField("url", StringType(), nullable=True),
    StructField("date", StringType(), nullable=True),
    StructField("short_description", StringType(), nullable=True),
    StructField("text", StringType(), nullable=True),
    StructField("publisher", MapType(StringType(), StringType()), nullable=True),
    StructField("convertedDate", TimestampType(), nullable=True)
])


df_concatenated = df.withColumn("articles_concatenated", concat_ws(",", "articles"))

# Parse the concatenated string as JSON
df_parsed = df_concatenated.withColumn("articles_parsed", from_json("articles", schema))

# Group by '_id' and count the number of articles for each ID
df_count = df_exploded.groupBy("_id").count()

# Rename columns as needed
df_result = df_count.withColumnRenamed("_id", "id").withColumnRenamed("count", "article_count")
df_result.show()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[50], line 34
#      31 df_concatenated = df.withColumn("articles_concatenated", concat_ws(",", "articles"))
#      33 # Parse the concatenated string as JSON
# ---> 34 df_parsed = df_concatenated.withColumn("articles_parsed", from_json("articles", schema))
#      36 # Group by '_id' and count the number of articles for each ID
#      37 df_count = df_exploded.groupBy("_id").count()
#
# File ~/anaconda3/envs/DistributedComputing/lib/python3.11/site-packages/pyspark/sql/dataframe.py:5174, in DataFrame.withColumn(self, colName, col)
#    5169 if not isinstance(col, Column):
#    5170     raise PySparkTypeError(
#    5171         error_class="NOT_COLUMN",
#    5172         message_parameters={"arg_name": "col", "arg_type": type(col).__name__},
#    5173     )
# -> 5174 return DataFrame(self._jdf.withColumn(colName, col._jc), self.sparkSession)
#
# File ~/anaconda3/envs/DistributedComputing/lib/python3.11/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File ~/anaconda3/envs/DistributedComputing/lib/python3.11/site-packages/pyspark/errors/exceptions/captured.py:185, in capture_sql_exception.<locals>.deco(*a, **kw)
#     181 converted = convert_exception(e.java_exception)
#     182 if not isinstance(converted, UnknownException):
#     183     # Hide where the exception came from that shows a non-Pythonic
#     184     # JVM exception message.
# --> 185     raise converted from None
#     186 else:
#     187     raise
#
# AnalysisException: [DATATYPE_MISMATCH.UNEXPECTED_INPUT_TYPE] Cannot resolve "from_json(articles)" due to data type mismatch: Parameter 1 requires the "STRING" type, however "articles" has the type "ARRAY<STRING>".;
# 'Project [_id#276, count#277, articles#278, articles_concatenated#282, from_json(StructField(_id,StringType,false), StructField(title,StringType,true), StructField(top_image,StringType,true), StructField(images,ArrayType(StringType,true),true), StructField(videos,ArrayType(StringType,true),true), StructField(url,StringType,true), StructField(date,StringType,true), StructField(short_description,StringType,true), StructField(text,StringType,true), StructField(publisher,MapType(StringType,StringType,true),true), StructField(convertedDate,TimestampType,true), articles#278, Some(America/Los_Angeles)) AS articles_parsed#287]
# +- Project [_id#276, count#277, articles#278, concat_ws(,, articles#278) AS articles_concatenated#282]
#    +- LogicalRDD [_id#276, count#277, articles#278], false

# %%
df_parsed.show()
# Out:
# +----------+-----+--------------------+---------------------+---------------+
# |       _id|count|            articles|articles_concatenated|articles_parsed|
# +----------+-----+--------------------+---------------------+---------------+
# |2020-02-05|    1|[[, {, ', _, i, d...| [,{,',_,i,d,',:, ...|           NULL|
# |2024-01-24|    1|[[, {, ', _, i, d...| [,{,',_,i,d,',:, ...|           NULL|
# |2023-10-01|    1|[[, {, ', _, i, d...| [,{,',_,i,d,',:, ...|           NULL|
# |2024-02-28|   22|[[, {, ', _, i, d...| [,{,',_,i,d,',:, ...|           NULL|
# |2023-01-03|    1|[[, {, ', _, i, d...| [,{,',_,i,d,',:, ...|           NULL|
# |2024-01-17|    1|[[, {, ', _, i, d...| [,{,',_,i,d,',:, ...|           NULL|
# |2024-01-18|    1|[[, {, ', _, i, d...| [,{,',_,i,d,',:, ...|           NULL|
# |2023-11-20|    1|[[, {, ', _, i, d...| [,{,',_,i,d,',:, ...|           NULL|
# |2023-05-07|    1|[[, {, ', _, i, d...| [,{,',_,i,d,',:, ...|           NULL|
# |2018-09-28|    1|[[, {, ', _, i, d...| [,{,',_,i,d,',:, ...|           NULL|
# |2023-10-09|    1|[[, {, ', _, i, d...| [,{,',_,i,d,',:, ...|           NULL|
# |2022-11-10|    1|[[, {, ', _, i, d...| [,{,',_,i,d,',:, ...|           NULL|
# |2024-02-24|    5|[[, {, ', _, i, d...| [,{,',_,i,d,',:, ...|           NULL|
# |2023-09-29|    1|[[, {, ', _, i, d...| [,{,',_,i,d,',:, ...|           NULL|
# |2023-09-28|    1|[[, {, ', _, i, d...| [,{,',_,i,d,',:, ...|           NULL|
# |2024-02-04|    1|[[, {, ', _, i, d...| [,{,',_,i,d,',:, ...|           NULL|
# |2024-02-29|    9|[[, {, ', _, i, d...| [,{,',_,i,d,',:, ...|           NULL|
# |2023-05-26|    1|[[, {, ', _, i, d...| [,{,',_,i,d,',:, ...|           NULL|
# |2024-02-08|    5|[[, {, ', _, i, d...| [,{,',_,i,d,',:, ...|           NULL|
# |2019-10-29|    1|[[, {, ', _, i, d...| [,{,',_,i,d,',:, ...|           NULL|
# +----------+-----+--------------------+---------------------+---------------+
# only showing top 20 rows

# %%
df_count.show()
# Out:
# +----------+-----+
# |       _id|count|
# +----------+-----+
# |2024-02-28|69417|
# |2023-01-03|14007|
# |2020-02-05|  765|
# |2023-11-20| 2864|
# |2024-01-17| 2684|
# |2024-01-18| 4394|
# |2023-10-01| 4709|
# |2024-01-24| 3446|
# |2024-02-04| 5888|
# |2022-11-10| 3266|
# |2023-09-28| 6365|
# |2018-09-28| 2232|
# |2023-05-07| 4115|
# |2023-09-29| 5387|
# |2024-02-24|17682|
# |2023-10-09| 5801|
# |2024-02-08|17561|
# |2024-03-02| 5554|
# |2019-10-29| 1923|
# |2022-07-12| 4619|
# +----------+-----+
# only showing top 20 rows

# %%
df_exploded.show()
# Out:
# +----------+-----+--------------------+-------+
# |       _id|count|            articles|article|
# +----------+-----+--------------------+-------+
# |2020-02-05|    1|[[, {, ', _, i, d...|      [|
# |2020-02-05|    1|[[, {, ', _, i, d...|      {|
# |2020-02-05|    1|[[, {, ', _, i, d...|      '|
# |2020-02-05|    1|[[, {, ', _, i, d...|      _|
# |2020-02-05|    1|[[, {, ', _, i, d...|      i|
# |2020-02-05|    1|[[, {, ', _, i, d...|      d|
# |2020-02-05|    1|[[, {, ', _, i, d...|      '|
# |2020-02-05|    1|[[, {, ', _, i, d...|      :|
# |2020-02-05|    1|[[, {, ', _, i, d...|       |
# |2020-02-05|    1|[[, {, ', _, i, d...|      O|
# |2020-02-05|    1|[[, {, ', _, i, d...|      b|
# |2020-02-05|    1|[[, {, ', _, i, d...|      j|
# |2020-02-05|    1|[[, {, ', _, i, d...|      e|
# |2020-02-05|    1|[[, {, ', _, i, d...|      c|
# |2020-02-05|    1|[[, {, ', _, i, d...|      t|
# |2020-02-05|    1|[[, {, ', _, i, d...|      I|
# |2020-02-05|    1|[[, {, ', _, i, d...|      d|
# |2020-02-05|    1|[[, {, ', _, i, d...|      (|
# |2020-02-05|    1|[[, {, ', _, i, d...|      '|
# |2020-02-05|    1|[[, {, ', _, i, d...|      6|
# +----------+-----+--------------------+-------+
# only showing top 20 rows

# %%
df.show()
# Out:
# +----------+-----+--------------------+
# |       _id|count|            articles|
# +----------+-----+--------------------+
# |2020-02-05|    1|[[, {, ', _, i, d...|
# |2024-01-24|    1|[[, {, ', _, i, d...|
# |2023-10-01|    1|[[, {, ', _, i, d...|
# |2024-02-28|   22|[[, {, ', _, i, d...|
# |2023-01-03|    1|[[, {, ', _, i, d...|
# |2024-01-17|    1|[[, {, ', _, i, d...|
# |2024-01-18|    1|[[, {, ', _, i, d...|
# |2023-11-20|    1|[[, {, ', _, i, d...|
# |2023-05-07|    1|[[, {, ', _, i, d...|
# |2018-09-28|    1|[[, {, ', _, i, d...|
# |2023-10-09|    1|[[, {, ', _, i, d...|
# |2022-11-10|    1|[[, {, ', _, i, d...|
# |2024-02-24|    5|[[, {, ', _, i, d...|
# |2023-09-29|    1|[[, {, ', _, i, d...|
# |2023-09-28|    1|[[, {, ', _, i, d...|
# |2024-02-04|    1|[[, {, ', _, i, d...|
# |2024-02-29|    9|[[, {, ', _, i, d...|
# |2023-05-26|    1|[[, {, ', _, i, d...|
# |2024-02-08|    5|[[, {, ', _, i, d...|
# |2019-10-29|    1|[[, {, ', _, i, d...|
# +----------+-----+--------------------+
# only showing top 20 rows
